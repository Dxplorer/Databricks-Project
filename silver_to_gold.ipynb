# %%
# %sql
MERGE INTO servicenowapril26.edw_gold.dim_category AS target
USING (
  SELECT DISTINCT
    category AS Category,
    subcategory AS Subcategory
  FROM servicenowapril26.edw_silver.servicenow_event_log
) AS source
ON target.Category = source.Category
   AND target.Subcategory = source.Subcategory
WHEN NOT MATCHED THEN
  INSERT (Category, Subcategory)
  VALUES (source.Category, source.Subcategory);
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>num_affected_rows</th><th>num_updated_rows</th><th>num_deleted_rows</th><th>num_inserted_rows</th></tr></thead><tbody><tr><td>62</td><td>0</td><td>0</td><td>62</td></tr></tbody></table></div>

# %%
# %sql
MERGE INTO servicenowapril26.edw_gold.dim_user AS target
USING (
  SELECT DISTINCT
    opened_by  AS opened_by
  FROM servicenowapril26.edw_silver.servicenow_event_log
  WHERE opened_by IS NOT NULL
) AS source
ON target.openedby = source.opened_by
WHEN NOT MATCHED AND source.opened_by IS NOT NULL THEN
  INSERT (openedby, SysCreatedBy, SysUpdatedBy)
  VALUES (source.opened_by, NULL, NULL);
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>num_affected_rows</th><th>num_updated_rows</th><th>num_deleted_rows</th><th>num_inserted_rows</th></tr></thead><tbody><tr><td>24</td><td>0</td><td>0</td><td>24</td></tr></tbody></table></div>

# %%
# %sql
MERGE INTO servicenowapril26.edw_gold.fact_event_log AS target

USING (
  SELECT *
  FROM (
    SELECT
      s.number AS Number,
      u.UserId,
      c.CategoryId,
      to_timestamp(s.opened_at, 'd/M/yyyy H:mm') AS OpenedAt,
      ROW_NUMBER() OVER (
        PARTITION BY s.number, u.UserId, c.CategoryId
        ORDER BY s.opened_at DESC
      ) AS rn
    FROM servicenowapril26.edw_silver.servicenow_event_log s
    LEFT JOIN servicenowapril26.edw_gold.dim_user u
      ON s.opened_by = u.OpenedBy
    LEFT JOIN servicenowapril26.edw_gold.dim_category c
      ON s.category = c.Category
      AND s.subcategory = c.Subcategory
  ) deduped
  WHERE rn = 1
) AS source
ON target.Number = source.Number
   AND target.UserId = source.UserId
   AND target.CategoryId = source.CategoryId
WHEN MATCHED THEN
  UPDATE SET
    target.OpenedAt = source.OpenedAt
WHEN NOT MATCHED THEN
  INSERT (Number, UserId, CategoryId, OpenedAt)
  VALUES (source.Number, source.UserId, source.CategoryId, source.OpenedAt);
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>num_affected_rows</th><th>num_updated_rows</th><th>num_deleted_rows</th><th>num_inserted_rows</th></tr></thead><tbody><tr><td>229</td><td>0</td><td>0</td><td>229</td></tr></tbody></table></div>
